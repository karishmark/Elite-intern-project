# %%
# import the libiaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
df_diamond = pd.read_csv("diamonds.csv")
df_diamond
# Out:
#          sno  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
df_diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sno      53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   color    53940 non-null  object
#  4   clarity  53940 non-null  object
#  5   depth    53940 non-null  float64
#  6   table    53940 non-null  float64
#  7   price    53940 non-null  int64
#  8   x        53940 non-null  float64
#  9   y        53940 non-null  float64
#  10  z        53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
#checking the missing values
df_diamond.isnull().sum()
# Out:
# sno        0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#statistics numerical columns 
df_diamond.describe()
# Out:
#                 sno         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
#check unique values
df_diamond["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#data visualzation 
sns.set_style("whitegrid")

# %%
#distribuation of diamond price
plt.figure(figsize= (4,4))
sns.histplot(df_diamond["price"], bins=45, kde= True, color= "red")
plt.title("DISTRIBUATION OF DIAMOND PRICE")
plt.xlabel("price")
plt.ylabel("count")
plt.show()

# %%
# boxplot of carat vs price
plt.figure(figsize= (4,4))
sns.boxplot(x = "carat", y = "price", data = df_diamond, palette="coolwarm")
plt.xlabel("carat weight")
plt.ylabel("price of the diamond")
plt.title("CARAT VS PRICE")
plt.xticks(rotation = 45)
plt.show()
# Out:
# C:\Users\veena\AppData\Local\Temp\ipykernel_2308\3365320929.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = "carat", y = "price", data = df_diamond, palette="coolwarm")

# %%
#scatter plot cut vs carat
plt.figure(figsize=(4,4))
sns.scatterplot(x = "cut", y = "carat", data = df_diamond, alpha = 0.5, color = "purple")
plt.title("CUT VS carat")
plt.xlabel("cut")
plt.ylabel("carat")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

categorical_columns = ["cut", "color", "clarity"]
for col in categorical_columns:
    df_diamond[col] = label_encoder.fit_transform(df_diamond[col])
    
plt.figure(figsize=(8,4))
sns.heatmap(df_diamond.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("FEATURE OF CORRELATION MATRIX")
plt.show()
